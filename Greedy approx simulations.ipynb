# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from networkenv import NetworkEnv
import game
import networkx as nx
from utils import create_approx_greedy_player

# %%
# create some rules for the game
r = game.Rules()
r.nb_max_step = 10
r.nb_players = 5
SIM_SIZE = 100
sim_values = np.zeros([SIM_SIZE, r.nb_players])

# create a game with these rules
g = game.Game(r)
for i in range(r.nb_players):
    greedy_player = create_approx_greedy_player("Player {}".format(i), r, eps=.2, delta=.05)
    g.add_player(greedy_player)

# create an RL environment with with game
env = NetworkEnv(g)
for i in range(SIM_SIZE):
    env.reset()
    time1 = time.time()
    print("Starting game {}".format(i))
    for j in range(r.nb_max_step):
        env.game.play_round()
    time2 = time.time()
    print("Finished game {0} in {1} seconds".format(i, (time2-time1)))
    final_vals = list(nx.betweenness_centrality(env.game.graph).values())
    sim_values[i] = final_vals
# Out:
# Starting game 0
# Finished game 0 in 16.233708143234253 seconds
# Starting game 1
# Finished game 1 in 25.468188047409058 seconds
# Starting game 2
# Finished game 2 in 16.902592182159424 seconds
# Starting game 3
# Finished game 3 in 16.965267181396484 seconds
# Starting game 4
# Finished game 4 in 12.455220937728882 seconds
# Starting game 5
# Finished game 5 in 9.37251901626587 seconds
# Starting game 6
# Finished game 6 in 9.756088972091675 seconds
# Starting game 7
# Finished game 7 in 8.942525863647461 seconds
# Starting game 8
# Finished game 8 in 8.731940031051636 seconds
# Starting game 9
# Finished game 9 in 9.033190965652466 seconds
# Starting game 10
# Finished game 10 in 14.003718852996826 seconds
# Starting game 11
# Finished game 11 in 8.808636903762817 seconds
# Starting game 12
# Finished game 12 in 7.361041069030762 seconds
# Starting game 13
# Finished game 13 in 6.679178953170776 seconds
# Starting game 14
# Finished game 14 in 8.008893966674805 seconds
# Starting game 15
# Finished game 15 in 13.683194875717163 seconds
# Starting game 16
# Finished game 16 in 15.704657077789307 seconds
# Starting game 17
# Finished game 17 in 8.804427146911621 seconds
# Starting game 18
# Finished game 18 in 8.020737171173096 seconds
# Starting game 19
# Finished game 19 in 7.411569833755493 seconds
# Starting game 20
# Finished game 20 in 9.210453033447266 seconds
# Starting game 21
# Finished game 21 in 8.358378171920776 seconds
# Starting game 22
# Finished game 22 in 10.306649923324585 seconds
# Starting game 23
# Finished game 23 in 10.31079912185669 seconds
# Starting game 24
# Finished game 24 in 10.209681987762451 seconds
# Starting game 25
# Finished game 25 in 12.173982858657837 seconds
# Starting game 26
# Finished game 26 in 8.408894062042236 seconds
# Starting game 27
# Finished game 27 in 8.134252071380615 seconds
# Starting game 28
# Finished game 28 in 8.791976928710938 seconds
# Starting game 29
# Finished game 29 in 7.408850908279419 seconds
# Starting game 30
# Finished game 30 in 8.006083011627197 seconds
# Starting game 31
# Finished game 31 in 7.448253870010376 seconds
# Starting game 32
# Finished game 32 in 10.913222074508667 seconds
# Starting game 33
# Finished game 33 in 11.735136032104492 seconds
# Starting game 34
# Finished game 34 in 9.672176122665405 seconds
# Starting game 35
# Finished game 35 in 10.162562847137451 seconds
# Starting game 36
# Finished game 36 in 11.468109846115112 seconds
# Starting game 37
# Finished game 37 in 12.01404094696045 seconds
# Starting game 38
# Finished game 38 in 9.244041204452515 seconds
# Starting game 39
# Finished game 39 in 8.398566961288452 seconds
# Starting game 40
# Finished game 40 in 7.640733003616333 seconds
# Starting game 41
# Finished game 41 in 10.179014921188354 seconds
# Starting game 42
# Finished game 42 in 8.561584949493408 seconds
# Starting game 43
# Finished game 43 in 7.683764934539795 seconds
# Starting game 44
# Finished game 44 in 9.509607076644897 seconds
# Starting game 45
# Finished game 45 in 8.569811820983887 seconds
# Starting game 46
# Finished game 46 in 8.990952014923096 seconds
# Starting game 47
# Finished game 47 in 13.78158688545227 seconds
# Starting game 48
# Finished game 48 in 10.797715187072754 seconds
# Starting game 49
# Finished game 49 in 11.701733112335205 seconds
# Starting game 50
# Finished game 50 in 13.325195074081421 seconds
# Starting game 51
# Finished game 51 in 11.688344955444336 seconds
# Starting game 52
# Finished game 52 in 9.272763967514038 seconds
# Starting game 53
# Finished game 53 in 8.678920030593872 seconds
# Starting game 54
# Finished game 54 in 8.82705307006836 seconds
# Starting game 55
# Finished game 55 in 9.351582050323486 seconds
# Starting game 56
# Finished game 56 in 8.888007879257202 seconds
# Starting game 57
# Finished game 57 in 10.469255924224854 seconds
# Starting game 58
# Finished game 58 in 10.468570947647095 seconds
# Starting game 59
# Finished game 59 in 11.383965015411377 seconds
# Starting game 60
# Finished game 60 in 19.946825981140137 seconds
# Starting game 61
# Finished game 61 in 10.574871063232422 seconds
# Starting game 62
# Finished game 62 in 8.162410974502563 seconds
# Starting game 63
# Finished game 63 in 7.216438055038452 seconds
# Starting game 64
# Finished game 64 in 7.800896167755127 seconds
# Starting game 65
# Finished game 65 in 8.521919965744019 seconds
# Starting game 66
# Finished game 66 in 6.239731788635254 seconds
# Starting game 67
# Finished game 67 in 7.2378928661346436 seconds
# Starting game 68
# Finished game 68 in 6.842295169830322 seconds
# Starting game 69
# Finished game 69 in 7.7005510330200195 seconds
# Starting game 70
# Finished game 70 in 8.043853998184204 seconds
# Starting game 71
# Finished game 71 in 7.682910919189453 seconds
# Starting game 72
# Finished game 72 in 7.920328140258789 seconds
# Starting game 73
# Finished game 73 in 8.372011184692383 seconds
# Starting game 74
# Finished game 74 in 8.556172847747803 seconds
# Starting game 75
# Finished game 75 in 9.149252891540527 seconds
# Starting game 76
# Finished game 76 in 9.915898084640503 seconds
# Starting game 77
# Finished game 77 in 8.249888896942139 seconds
# Starting game 78
# Finished game 78 in 9.27017092704773 seconds
# Starting game 79
# Finished game 79 in 8.987943887710571 seconds
# Starting game 80
# Finished game 80 in 10.825030088424683 seconds
# Starting game 81
# Finished game 81 in 9.554046154022217 seconds
# Starting game 82
# Finished game 82 in 14.231247186660767 seconds
# Starting game 83
# Finished game 83 in 17.399794101715088 seconds
# Starting game 84
# Finished game 84 in 15.864948034286499 seconds
# Starting game 85
# Finished game 85 in 13.850651025772095 seconds
# Starting game 86
# Finished game 86 in 11.471994876861572 seconds
# Starting game 87
# Finished game 87 in 8.408315896987915 seconds
# Starting game 88
# Finished game 88 in 8.981101989746094 seconds
# Starting game 89
# Finished game 89 in 7.949105978012085 seconds
# Starting game 90
# Finished game 90 in 8.294065952301025 seconds
# Starting game 91
# Finished game 91 in 8.981653928756714 seconds
# Starting game 92
# Finished game 92 in 11.200530052185059 seconds
# Starting game 93
# Finished game 93 in 11.276978969573975 seconds
# Starting game 94
# Finished game 94 in 12.050884008407593 seconds
# Starting game 95
# Finished game 95 in 9.66201400756836 seconds
# Starting game 96
# Finished game 96 in 10.260382175445557 seconds
# Starting game 97
# Finished game 97 in 10.64490008354187 seconds
# Starting game 98
# Finished game 98 in 9.238972902297974 seconds
# Starting game 99
# Finished game 99 in 7.58434796333313 seconds

# %%
means = sim_values.mean(axis=0)
variance = sim_values.var(axis=0)

# %%
# %matplotlib inline
plt.style.use("seaborn-whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(12, 7)
ax.errorbar(x = np.arange(5),  y = means, yerr=variance, fmt='o', lw=3)
plt.suptitle("Simulation of 100 games with symmetric approximate greedy " +
             "($\epsilon = .2$, $\delta = .05$) players", fontsize=16)
plt.ylabel("Betweenness Centrality", fontsize=15)
plt.xlabel("Player", fontsize=15)
